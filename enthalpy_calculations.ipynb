# %%
import pandas as pd

# Load the CSV file into a DataFrame
df_pure_water = pd.read_csv('pure_water_data.csv')
print (df_pure_water.columns)
# Out:
# Index(['#"Step"', 'Time (ps)', 'Potential Energy (kJ/mole)',
#        'Kinetic Energy (kJ/mole)', 'Total Energy (kJ/mole)', 'Temperature (K)',
#        'Box Volume (nm^3)', 'Density (g/mL)', 'Speed (ns/day)',
#        'Elapsed Time (s)'],
#       dtype='object')

# %%
pure_water_total_energy = df_pure_water["Total Energy (kJ/mole)"].mean()
print (pure_water_total_energy, 'kJ/mole')

pure_water_total_energy_new = df_pure_water["Total Energy (kJ/mole)"][100:].mean()
print (pure_water_total_energy_new, 'kJ/mole')
# Out:
# -16258.799124212463 kJ/mole
# -16256.393645085047 kJ/mole

# %%
pure_water_volume = df_pure_water["Box Volume (nm^3)"].mean()
print (pure_water_volume, 'nm^3')

pure_water_volume = df_pure_water["Box Volume (nm^3)"][100:].mean()
print (pure_water_volume, 'nm^3')
# Out:
# 15.192501559435414 nm^3
# 15.19280808073194 nm^3

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df_pure_dmso = pd.read_csv('pure_dmso_data.csv')
print (df_pure_dmso.columns)
# Out:
# Index(['#"Step"', 'Time (ps)', 'Potential Energy (kJ/mole)',
#        'Kinetic Energy (kJ/mole)', 'Total Energy (kJ/mole)', 'Temperature (K)',
#        'Box Volume (nm^3)', 'Density (g/mL)', 'Speed (ns/day)',
#        'Elapsed Time (s)'],
#       dtype='object')

# %%
pure_dmso_total_energy = df_pure_dmso["Total Energy (kJ/mole)"].mean()
print (pure_dmso_total_energy, 'kJ/mole')
# Out:
# -52420.24427749845 kJ/mole

# %%
pure_dmso_volume = df_pure_dmso["Box Volume (nm^3)"].mean()
print (pure_dmso_volume, 'nm^3')
# Out:
# 62.05699038311695 nm^3

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df_dmso_water = pd.read_csv('dmso_water_data2.csv')
print (df_dmso_water.columns)
# Out:
# Index(['#"Step"', 'Time (ps)', 'Potential Energy (kJ/mole)',
#        'Kinetic Energy (kJ/mole)', 'Total Energy (kJ/mole)', 'Temperature (K)',
#        'Box Volume (nm^3)', 'Density (g/mL)', 'Speed (ns/day)',
#        'Elapsed Time (s)'],
#       dtype='object')

# %%
dmso_water_total_energy = df_dmso_water["Total Energy (kJ/mole)"].mean()
print (dmso_water_total_energy, 'kJ/mole')

dmso_water_total_energy = df_dmso_water["Total Energy (kJ/mole)"][100:].mean()
print (dmso_water_total_energy, 'kJ/mole')
# Out:
# -26322.465089681053 kJ/mole
# -26326.186014147162 kJ/mole

# %%
dmso_water_volume = df_dmso_water["Box Volume (nm^3)"].mean()
print (dmso_water_volume, 'nm^3')

dmso_water_volume = df_dmso_water["Box Volume (nm^3)"][100:].mean()
print (dmso_water_volume, 'nm^3')
# Out:
# 26.751505263513458 nm^3
# 26.738914106818523 nm^3

# %%
potential_energy = df_pure_water["Potential Energy (kJ/mole)"].mean()
print (potential_energy, 'kJ/mol')
# Out:
# -20001.1973599255 kJ/mol

# %%
potential_energy = df_pure_dmso["Potential Energy (kJ/mole)"].mean()
print (potential_energy, 'kJ/mol')
# Out:
# -67394.4718322877 kJ/mol

# %%
potential_energy = df_dmso_water["Potential Energy (kJ/mole)"].mean()
print (potential_energy, 'kJ/mol')
# Out:
# -32872.67422880845 kJ/mol

# %%
import matplotlib.pyplot as plt
plt.plot (df_pure_water["Time (ps)"][100:], df_pure_water["Total Energy (kJ/mole)"][100:])

plt.xlabel ("Time (ps)")
plt.ylabel ("Total Energy (kJ/mol)")
plt.title ("Total Energy vs Time for Pure Water")
plt.grid = True

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot (df_pure_water["Time (ps)"][100:], df_pure_water["Box Volume (nm^3)"][100:])

plt.xlabel ("Time (ps)")
plt.ylabel ("Total Volume (nm^3)")
plt.title ("Total Volume vs Time for Pure Water")
plt.grid = True

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot (df_pure_dmso["Time (ps)"], df_pure_dmso["Total Energy (kJ/mole)"])

plt.xlabel ("Time (ps)")
plt.ylabel ("Total Energy (kJ/mol)")
plt.title ("Total Energy vs Time for Pure DMSO")
plt.grid = True

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot (df_pure_dmso["Time (ps)"], df_pure_dmso["Box Volume (nm^3)"])

plt.xlabel ("Time (ps)")
plt.ylabel ("Total Volume (nm^3)")
plt.title ("Total Volume vs Time for Pure DMSO")
plt.grid = True

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot (df_dmso_water["Time (ps)"][100:], df_dmso_water["Total Energy (kJ/mole)"][100:])

plt.xlabel ("Time (ps)")
plt.ylabel ("Total Energy (kJ/mol)")
plt.title ("Total Energy vs Time for DMSO Water Mixture")
plt.grid = True

plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot (df_dmso_water["Time (ps)"][100:], df_dmso_water["Box Volume (nm^3)"][100:])

plt.xlabel ("Time (ps)")
plt.ylabel ("Total Volume (nm^3)")
plt.title ("Total Volume vs Time for DMSO Water Mixture")
plt.grid = True

plt.show()

# %%
import sys
print(sys.executable)
# Out:
# /projects/ladu6977/polyzymd/.pixi/envs/cuda-12-4/bin/python

# %%
import pymbar
# Out:
# Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
# ****** PyMBAR will use 64-bit JAX! *******
# * JAX is currently set to 32-bit bitsize *
# * which is its default.                  *
# *                                        *
# * PyMBAR requires 64-bit mode and WILL   *
# * enable JAX's 64-bit mode when called.  *
# *                                        *
# * This MAY cause problems with other     *
# * Uses of JAX in the same code.          *
# ******************************************

# %%
from pymbar import timeseries

A_t = df_pure_water["Total Energy (kJ/mole)"]

t0, g, Neff_max = timeseries.detect_equilibration(A_t) # compute indices of uncorrelated timeseries
print(f"t0: {t0}")
print(f"g: {g}")
print(f"Neff_max: {Neff_max}")
A_t_equil = A_t[t0:]
indices = timeseries.subsample_correlated_data(A_t_equil, g=g)
A_n = A_t_equil.iloc[indices]
# Out:
# t0: 1
# g: 1.0
# Neff_max: 1000.0

# %%
equil_pure_water_total_energy = A_n.mean()
print (equil_pure_water_total_energy, "kJ/mol")
# Out:
# -16257.861674681753 kJ/mol

# %%
A_t2 = df_pure_dmso["Total Energy (kJ/mole)"]

t0, g, Neff_max = timeseries.detect_equilibration(A_t2) # compute indices of uncorrelated timeseries
print(f"t0: {t0}")
print(f"g: {g}")
print(f"Neff_max: {Neff_max}")
A_t2_equil = A_t2[t0:]
indices = timeseries.subsample_correlated_data(A_t2_equil, g=g)
A_n2 = A_t2_equil.iloc[indices]
# Out:
# t0: 40
# g: 1.0
# Neff_max: 961.0

# %%
equil_pure_dmso_total_energy = A_n2.mean()
print (equil_pure_dmso_total_energy, "kJ/mol")
# Out:
# -52419.84916886979 kJ/mol

# %%
A_t3 = df_dmso_water["Total Energy (kJ/mole)"]

t0, g, Neff_max = timeseries.detect_equilibration(A_t3) # compute indices of uncorrelated timeseries
print(f"t0: {t0}")
print(f"g: {g}")
print(f"Neff_max: {Neff_max}")
A_t3_equil = A_t3[t0:]
indices = timeseries.subsample_correlated_data(A_t3_equil, g=g)
A_n3 = A_t3_equil.iloc[indices]
# Out:
# t0: 10
# g: 1.2172077894210815
# Neff_max: 814.158447265625

# %%
equil_dmso_water_total_energy = A_n3.mean()
print (equil_dmso_water_total_energy, "kJ/mol")
# Out:
# -26323.946291455373 kJ/mol

# %%
A_t_v = df_pure_water["Box Volume (nm^3)"]

t0, g, Neff_max = timeseries.detect_equilibration(A_t_v) # compute indices of uncorrelated timeseries
print(f"t0: {t0}")
print(f"g: {g}")
print(f"Neff_max: {Neff_max}")
A_t_v_equil = A_t_v[t0:]
indices = timeseries.subsample_correlated_data(A_t_v_equil, g=g)
A_n_v = A_t_v_equil.iloc[indices]
# Out:
# t0: 1
# g: 1.0
# Neff_max: 1000.0

# %%
equil_pure_water_volume = A_n_v.mean()
print (equil_pure_water_volume, "nm^3")
# Out:
# 15.195813596024536 nm^3

# %%
A_t2_v = df_pure_dmso["Box Volume (nm^3)"]

t0, g, Neff_max = timeseries.detect_equilibration(A_t2_v) # compute indices of uncorrelated timeseries
print(f"t0: {t0}")
print(f"g: {g}")
print(f"Neff_max: {Neff_max}")
A_t2_v_equil = A_t2_v[t0:]
indices = timeseries.subsample_correlated_data(A_t2_v_equil, g=g)
A_n2_v = A_t2_v_equil.iloc[indices]
# Out:
# t0: 0
# g: 1.2567393779754639
# Neff_max: 796.505615234375

# %%
equil_pure_dmso_volume = A_n2_v.mean()
print (equil_pure_dmso_volume, "nm^3")
# Out:
# 62.047963245213914 nm^3

# %%
A_t3_v = df_dmso_water["Box Volume (nm^3)"]

t0, g, Neff_max = timeseries.detect_equilibration(A_t3_v) # compute indices of uncorrelated timeseries
print(f"t0: {t0}")
print(f"g: {g}")
print(f"Neff_max: {Neff_max}")
A_t3_v_equil = A_t3_v[t0:]
indices = timeseries.subsample_correlated_data(A_t3_v_equil, g=g)
A_n3_v = A_t3_v_equil.iloc[indices]
# Out:
# t0: 8
# g: 1.169437289237976
# Neff_max: 849.1263427734375

# %%
equil_dmso_water_volume = A_n3_v.mean()
print (equil_dmso_water_volume, "nm^3")
# Out:
# 26.737334034241357 nm^3
